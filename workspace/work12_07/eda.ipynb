# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
train_date = pd.read_csv('C:/Users/wgkdj/smbc_comp/input/train.csv')
test_date = pd.read_csv('C:/Users/wgkdj/smbc_comp/input/test.csv')

# %% [markdown]
# ## EDAします
# データのサイズ
# train (19984, 22)
# test (19702, 21)
# 二万件のデータなのでデータ数はあまり多くない印象を受ける(合計4万件)
# データの中身は大きく分けて２種類に分類できそう　木のデータと木の生えている地域のデータ
#
#
# データは３値分類です
# health
# 1    15751
# 0     3535
# 2      698
# 0:Fair（普通） 1:Good（良い） 2:Poor（悪い）１が多くなかなかやりおる
#
# ---null---
# steward       14883  木の管理者
# guards        14943　木のガードの有無　種類
# problems      12243　木の病気など
# ----------
#
# train_testで期間の差はない
# 2015/5　から　2016/10までなので約1か月半の間
#
# ラテン名と一般名称での表記ゆれはなさそうに（軽く見ただけなので要検証してください）
#
# どこに植えている木かというとニューヨーク州である　→　公園内部と歩道の大きく分けて二種類の場所に植えられている
#
# #####公園内######
# South Ozone Park    145　train_date[train_date['zip_city'].str.contains('park', case=False)]
# Ozone Park          129
# Rockaway Park        84
# Rego Park            48
# Floral Park          33
# Central Park         21
# ################
#
# 木の記録をつけている人が違う　→　人によって基準が違うかもしれない
# おそらく同じ木のデータはなさそう
# tree_dbh = 立木に人間が並んで立った時、人の胸の位置に当たる樹幹の部分の直径

# %%
train_date.isnull().sum()
# Out:
# Unnamed: 0        0
# created_at        0
# tree_dbh          0
# curb_loc          0
# health            0
# steward       14883
# guards        14943
# sidewalk          0
# user_type         0
# problems      12243
# spc_common        0
# spc_latin         0
# nta               0
# nta_name          0
# borocode          0
# boro_ct           0
# boroname          0
# zip_city          0
# cb_num            0
# st_senate         0
# st_assem          0
# cncldist          0
# dtype: int64

# %%
train_date.dtypes
# Out:
# Unnamed: 0     int64
# created_at    object
# tree_dbh       int64
# curb_loc      object
# health         int64
# steward       object
# guards        object
# sidewalk      object
# user_type     object
# problems      object
# spc_common    object
# spc_latin     object
# nta           object
# nta_name      object
# borocode       int64
# boro_ct        int64
# boroname      object
# zip_city      object
# cb_num         int64
# st_senate      int64
# st_assem       int64
# cncldist       int64
# dtype: object

# %%
train_date.head()
# Out:
#    Unnamed: 0  created_at  tree_dbh curb_loc  health steward   guards
# 0           0  2015-06-29        14   OnCurb       1     NaN      NaN  \
# 1           1  2016-09-21         5   OnCurb       1    3or4  Helpful
# 2           2  2015-09-13        26   OnCurb       2     NaN      NaN
# 3           3  2016-05-09        15   OnCurb       0     NaN      NaN
# 4           4  2016-06-24        23   OnCurb       1     NaN      NaN
#
#    sidewalk        user_type            problems          spc_common
# 0    Damage        Volunteer                 NaN         English oak  \
# 1  NoDamage        Volunteer                 NaN  crimson king maple
# 2  NoDamage        Volunteer  StonesBranchLights         English oak
# 3    Damage  NYC Parks Staff                 NaN         honeylocust
# 4  NoDamage        Volunteer              Stones    London planetree
#
#                             spc_latin   nta
# 0                       Quercus robur  QN45  \
# 1     Acer platanoides 'Crimson King'  BX05
# 2                       Quercus robur  SI01
# 3  Gleditsia triacanthos var. inermis  SI11
# 4               Platanus x acerifolia  MN03
#
#                                      nta_name  borocode  boro_ct
# 0        Douglas Manor-Douglaston-Little Neck         4  4152901  \
# 1                  Bedford Park-Fordham North         2  2039901
# 2  Annadale-Huguenot-Prince's Bay-Eltingville         5  5017011
# 3      Charleston-Richmond Valley-Tottenville         5  5024401
# 4           Central Harlem North-Polo Grounds         1  1022102
#
#         boroname       zip_city  cb_num  st_senate  st_assem  cncldist
# 0         Queens    Little Neck     411         11        25        23
# 1          Bronx          Bronx     207         33        78        15
# 2  Staten Island  Staten Island     503         24        62        51
# 3  Staten Island  Staten Island     503         24        62        51
# 4      Manhattan       New York     110         30        70         9

# %%
test_date.head()
# Out:
#    Unnamed: 0  created_at  tree_dbh curb_loc steward   guards  sidewalk
# 0       19984  2015-09-08        15   OnCurb     NaN      NaN    Damage  \
# 1       19985  2015-10-15         5   OnCurb    1or2      NaN  NoDamage
# 2       19986  2016-08-03         4   OnCurb     NaN   Unsure  NoDamage
# 3       19987  2015-08-06         7   OnCurb     NaN      NaN  NoDamage
# 4       19988  2015-10-21         6   OnCurb    1or2  Helpful  NoDamage
#
#           user_type problems         spc_common                     spc_latin
# 0   NYC Parks Staff      NaN       Callery pear              Pyrus calleryana  \
# 1         Volunteer      NaN             cherry                        Prunus
# 2         Volunteer      NaN  littleleaf linden                 Tilia cordata
# 3  TreesCount Staff      NaN       dawn redwood  Metasequoia glyptostroboides
# 4  TreesCount Staff   Stones   purple-leaf plum             Prunus cerasifera
#
#     nta                                        nta_name  borocode  boro_ct
# 0  BK17  Sheepshead Bay-Gerritsen Beach-Manhattan Beach         3  3062000  \
# 1  BX62                              Woodlawn-Wakefield         2  2045101
# 2  QN60                                     Kew Gardens         4  4013800
# 3  BK09                    Brooklyn Heights-Cobble Hill         3  3000301
# 4  BK75                                         Bedford         3  3025100
#
#    boroname     zip_city  cb_num  st_senate  st_assem  cncldist
# 0  Brooklyn     Brooklyn     315         22        45        48
# 1     Bronx        Bronx     212         34        81        11
# 2    Queens  Kew Gardens     409         14        27        29
# 3  Brooklyn     Brooklyn     302         26        52        33
# 4  Brooklyn     Brooklyn     303         25        56        36

# %%
train_date['created_at'] = pd.to_datetime(train_date['created_at'])
test_date['created_at'] = pd.to_datetime(test_date['created_at'])

# %%
train_date.sample(5)
# Out:
#        Unnamed: 0 created_at  tree_dbh curb_loc  health steward guards
# 9808         9808 2015-10-14         7   OnCurb       1     NaN    NaN  \
# 1157         1157 2015-11-30        17   OnCurb       1     NaN    NaN
# 3744         3744 2016-08-31        15   OnCurb       0     NaN    NaN
# 12539       12539 2016-07-15         2   OnCurb       1     NaN    NaN
# 10622       10622 2015-09-27         6   OnCurb       1     NaN    NaN
#
#        sidewalk         user_type         problems        spc_common
# 9808     Damage  TreesCount Staff              NaN  London planetree  \
# 1157   NoDamage         Volunteer        RootOther       honeylocust
# 3744   NoDamage   NYC Parks Staff  StonesRootOther           pin oak
# 12539  NoDamage         Volunteer     BranchLights      silver maple
# 10622    Damage   NYC Parks Staff              NaN  Japanese zelkova
#
#                                 spc_latin   nta
# 9808                Platanus x acerifolia  BK45  \
# 1157   Gleditsia triacanthos var. inermis  QN50
# 3744                    Quercus palustris  SI07
# 12539                    Acer saccharinum  SI25
# 10622                     Zelkova serrata  QN56
#
#                                              nta_name  borocode  boro_ct
# 9808   Georgetown-Marine Park-Bergen Beach-Mill Basin         3  3068600  \
# 1157                                 Elmhurst-Maspeth         4  4024300
# 3744                                      Westerleigh         5  5020100
# 12539                           Oakwood-Oakwood Beach         5  5013800
# 10622                                      Ozone Park         4  4005800
#
#             boroname       zip_city  cb_num  st_senate  st_assem  cncldist
# 9808        Brooklyn       Brooklyn     318         19        59        46
# 1157          Queens       Woodside     402         15        30        30
# 3744   Staten Island  Staten Island     501         23        61        49
# 12539  Staten Island  Staten Island     503         24        62        50
# 10622         Queens     Ozone Park     410         15        23        32

# %%
train_date['curb_loc'].value_counts()
# Out:
# curb_loc
# OnCurb            18777
# OffsetFromCurb     1207
# Name: count, dtype: int64

# %%
train_date['sidewalk'].value_counts()
# Out:
# sidewalk
# NoDamage    10689
# Damage       9295
# Name: count, dtype: int64

# %% [markdown]
# #########################################木の胸高直径####################################################

# %%
train_date['tree_dbh'].describe()
# Out:
# count    19984.000000
# mean        11.694906
# std          8.198150
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         17.000000
# max         42.000000
# Name: tree_dbh, dtype: float64

# %%
london_planetree_data = train_date[train_date['spc_common'] == 'London planetree']
# ヒストグラムを作成（tree_dbhは数値型なので注意）
plt.figure(figsize=(10, 6))
sns.histplot(data=london_planetree_data, x='tree_dbh', hue='health', multiple='stack',palette='viridis',bins=40)
plt.title('Distribution of tree_dbh for London planetree by Health')
plt.xlabel('tree_dbh')
plt.ylabel('Count')

# 凡例を表示
plt.legend(title='Health', loc='upper right', labels=['Health 0', 'Health 1', 'Health 2'])

# グリッドを表示
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
cherry_data = train_date[train_date['spc_common'] == 'cherry']
# ヒストグラムを作成（tree_dbhは数値型なので注意）
plt.figure(figsize=(10, 6))
sns.histplot(data=cherry_data, x='tree_dbh', hue='health', multiple='stack',palette='viridis',bins=40)
plt.title('Distribution of tree_dbh for  cherry by Health')
plt.xlabel('tree_dbh')
plt.ylabel('Count')

# 凡例を表示
plt.legend(title='Health', loc='upper right', labels=['Health 0', 'Health 1', 'Health 2'])

# グリッドを表示
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
pin_oak_data = train_date[train_date['spc_common'] == 'pin oak']
# ヒストグラムを作成（tree_dbhは数値型なので注意）
plt.figure(figsize=(10, 6))
sns.histplot(data=pin_oak_data, x='tree_dbh', hue='health', multiple='stack',palette='viridis',bins=40)
plt.title('Distribution of tree_dbh for  pin_oak by Health')
plt.xlabel('tree_dbh')
plt.ylabel('Count')

# 凡例を表示
plt.legend(title='Health', loc='upper right', labels=['Health 0', 'Health 1', 'Health 2'])

# グリッドを表示
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# 木の胸高経だけではわからない　おそらく子供の木や大人の木が混じっているように思う
# 木の種類ごとに見てみたが分布の違いがあり、それぞれの木で評価するのがいいのではないか？
# サクラの木はほか二つの分布から見て５付近に分布が位置している
# #####################################################################

# %%
train_date['problems'].value_counts()
# Out:
# problems
# Stones                                                       2219
# BranchLights                                                 1036
# StonesBranchLights                                            762
# BranchOther                                                   408
# RootOther                                                     333
# StonesTrunkOther                                              230
# RootOtherTrunkOtherBranchOther                                190
# TrunkOther                                                    183
# StonesBranchOther                                             180
# StonesRootOther                                               173
# WiresRope                                                     163
# StonesWiresRopeBranchLights                                   147
# MetalGrates                                                   139
# WiresRopeBranchLights                                          95
# RootOtherTrunkOther                                            92
# TrunkOtherBranchOther                                          84
# StonesRootOtherTrunkOther                                      72
# StonesTrunkOtherBranchOther                                    70
# RootOtherBranchOther                                           59
# RootOtherBranchLights                                          59
# StonesRootOtherWiresRopeBranchLights                           43
# WiresRopeBranchOther                                           43
# TrunkLights                                                    40
# BranchLightsBranchOther                                        38
# StonesRootOtherBranchOther                                     35
# StonesWiresRope                                                31
# TrunkOtherBranchLights                                         31
# StonesTrunkOtherBranchLights                                   30
# RootOtherWiresRope                                             30
# RootOtherWiresRopeTrunkOther                                   29
# StonesBranchLightsBranchOther                                  29
# MetalGratesRootOtherTrunkOther                                 29
# StonesWiresRopeTrunkLightsBranchLights                         29
# MetalGratesBranchOther                                         27
# TrunkLightsBranchLights                                        27
# StonesRootOtherTrunkOtherBranchLights                          27
# WiresRopeTrunkOtherBranchLightsBranchOther                     23
# WiresRopeTrunkOther                                            22
# StonesWiresRopeTrunkOtherBranchLights                          21
# StonesRootOtherBranchLights                                    21
# StonesWiresRopeBranchLightsBranchOther                         21
# RootOtherTrunkOtherBranchLights                                20
# RootOtherTrunkLightsBranchOther                                20
# RootOtherWiresRopeTrunkOtherBranchOther                        20
# RootOtherTrunkOtherBranchLightsBranchOther                     20
# StonesWiresRopeTrunkOther                                      20
# RootOtherWiresRopeBranchOther                                  19
# StonesMetalGratesBranchLights                                  18
# MetalGratesRootOtherBranchOther                                17
# RootOtherWiresRopeBranchLightsBranchOther                      17
# StonesMetalGrates                                              17
# MetalGratesTrunkOtherBranchOther                               16
# StonesRootOtherWiresRopeTrunkOtherBranchLightsBranchOther      15
# RootOtherWiresRopeBranchLights                                 14
# StonesMetalGratesWiresRopeTrunkLightsBranchLights              14
# MetalGratesTrunkOther                                          13
# StonesRootOtherBranchLightsBranchOther                         13
# TrunkOtherBranchLightsBranchOther                              13
# StonesTrunkOtherBranchLightsBranchOther                        13
# WiresRopeTrunkLights                                           12
# WiresRopeTrunkOtherBranchOther                                 12
# RootOtherWiresRopeTrunkOtherBranchLights                       12
# StonesWiresRopeBranchOther                                     12
# MetalGratesWiresRope                                           11
# RootOtherBranchLightsBranchOther                               11
# StonesSneakers                                                 10
# StonesTrunkLightsBranchLights                                   9
# RootOtherWiresRopeTrunkLights                                   8
# StonesRootOtherTrunkOtherBranchOther                            8
# StonesRootOtherWiresRopeBranchOther                             5
# StonesMetalGratesTrunkOther                                     4
# TrunkLightsBranchLightsBranchOther                              4
# WiresRopeTrunkLightsBranchLights                                4
# Name: count, dtype: int64

# %% [markdown]
# problemsの種類は多いと見せかけてあまり多くない　すべてこの値の組み合わせだ（StonesSneakersだけSneakersがある）
# Stones
# BranchLights
# BranchOther
# RootOther
# TrunkOther
# WiresRope
# MetalGrates
# TrunkLights

# %%
train_date['problems'].fillna(' ', inplace=True)

# %%
problem = ["Stones", "BranchLights", "BranchOther", "RootOther", "TrunkOther", "WiresRope", "MetalGrates", "TrunkLights"]
for substring in problem:
    train_date[substring] = train_date['problems'].apply(lambda row: 1 if substring in row else 0)

# X['errors?'] = X['errors?'].apply(lambda x: 1 if x == 'ERROR' else 0)

# %%
train_date.dtypes
# Out:
# Unnamed: 0               int64
# created_at      datetime64[ns]
# tree_dbh                 int64
# curb_loc                object
# health                   int64
# steward                 object
# guards                  object
# sidewalk                object
# user_type               object
# problems                object
# spc_common              object
# spc_latin               object
# nta                     object
# nta_name                object
# borocode                 int64
# boro_ct                  int64
# boroname                object
# zip_city                object
# cb_num                   int64
# st_senate                int64
# st_assem                 int64
# cncldist                 int64
# Stones                   int64
# BranchLights             int64
# BranchOther              int64
# RootOther                int64
# TrunkOther               int64
# WiresRope                int64
# MetalGrates              int64
# TrunkLights              int64
# dtype: object

# %%
filtered_data = train_date[train_date['zip_city'].str.contains('South Ozone Park', case=False)]

# %%
filtered_data[filtered_data['tree_dbh'] == 6]
# Out:
#        Unnamed: 0 created_at  tree_dbh        curb_loc  health steward
# 1008         1008 2016-09-02         6          OnCurb       1     NaN  \
# 2135         2135 2015-09-26         6          OnCurb       1     NaN
# 2293         2293 2015-12-21         6          OnCurb       1    1or2
# 2439         2439 2016-08-29         6  OffsetFromCurb       0    1or2
# 2652         2652 2016-06-15         6  OffsetFromCurb       2     NaN
# 5601         5601 2016-06-23         6          OnCurb       1    1or2
# 5705         5705 2016-06-10         6          OnCurb       1    1or2
# 6808         6808 2016-06-25         6          OnCurb       1     NaN
# 7422         7422 2016-06-27         6          OnCurb       1     NaN
# 7573         7573 2015-09-25         6          OnCurb       1    1or2
# 8081         8081 2015-11-19         6          OnCurb       0    1or2
# 8159         8159 2016-07-26         6          OnCurb       0     NaN
# 8345         8345 2015-10-14         6          OnCurb       1     NaN
# 8528         8528 2015-10-23         6          OnCurb       1    1or2
# 10116       10116 2015-10-14         6          OnCurb       1     NaN
# 13742       13742 2015-10-30         6          OnCurb       1    1or2
# 15149       15149 2015-11-03         6          OnCurb       1     NaN
# 18696       18696 2015-10-21         6          OnCurb       1    3or4
#
#         guards  sidewalk         user_type      problems        spc_common
# 1008       NaN    Damage  TreesCount Staff           NaN           pin oak  \
# 2135       NaN  NoDamage  TreesCount Staff           NaN   American linden
# 2293       NaN  NoDamage   NYC Parks Staff           NaN       Chinese elm
# 2439   Helpful  NoDamage  TreesCount Staff           NaN   American linden
# 2652       NaN  NoDamage         Volunteer           NaN            cherry
# 5601   Harmful  NoDamage         Volunteer           NaN      Callery pear
# 5705   Helpful  NoDamage         Volunteer           NaN           Sophora
# 6808   Helpful  NoDamage         Volunteer  BranchLights        white pine
# 7422    Unsure    Damage  TreesCount Staff           NaN  London planetree
# 7573       NaN    Damage         Volunteer  BranchLights         green ash
# 8081       NaN  NoDamage   NYC Parks Staff           NaN       Chinese elm
# 8159       NaN    Damage  TreesCount Staff           NaN   American linden
# 8345       NaN  NoDamage  TreesCount Staff           NaN      dawn redwood
# 8528   Helpful  NoDamage         Volunteer           NaN           pin oak
# 10116      NaN  NoDamage   NYC Parks Staff           NaN      Callery pear
# 13742      NaN  NoDamage         Volunteer           NaN         green ash
# 15149      NaN    Damage         Volunteer   MetalGrates         green ash
# 18696      NaN  NoDamage         Volunteer           NaN            cherry
#
#                           spc_latin   nta          nta_name  borocode
# 1008              Quercus palustris  QN55  South Ozone Park         4  \
# 2135                Tilia americana  QN55  South Ozone Park         4
# 2293               Ulmus parvifolia  QN55  South Ozone Park         4
# 2439                Tilia americana  QN55  South Ozone Park         4
# 2652                         Prunus  QN55  South Ozone Park         4
# 5601               Pyrus calleryana  QN55  South Ozone Park         4
# 5705        Styphnolobium japonicum  QN55  South Ozone Park         4
# 6808                  Pinus strobus  QN55  South Ozone Park         4
# 7422          Platanus x acerifolia  QN55  South Ozone Park         4
# 7573         Fraxinus pennsylvanica  QN55  South Ozone Park         4
# 8081               Ulmus parvifolia  QN55  South Ozone Park         4
# 8159                Tilia americana  QN55  South Ozone Park         4
# 8345   Metasequoia glyptostroboides  QN55  South Ozone Park         4
# 8528              Quercus palustris  QN55  South Ozone Park         4
# 10116              Pyrus calleryana  QN55  South Ozone Park         4
# 13742        Fraxinus pennsylvanica  QN55  South Ozone Park         4
# 15149        Fraxinus pennsylvanica  QN55  South Ozone Park         4
# 18696                        Prunus  QN55  South Ozone Park         4
#
#        boro_ct boroname          zip_city  cb_num  st_senate  st_assem
# 1008   4081800   Queens  South Ozone Park     410         10        31  \
# 2135   4081400   Queens  South Ozone Park     410         10        31
# 2293   4081400   Queens  South Ozone Park     410         10        31
# 2439   4081800   Queens  South Ozone Park     410         10        31
# 2652   4016800   Queens  South Ozone Park     410         10        31
# 5601   4010200   Queens  South Ozone Park     410         10        31
# 5705   4081800   Queens  South Ozone Park     410         10        31
# 6808   4081800   Queens  South Ozone Park     410         10        31
# 7422   4083800   Queens  South Ozone Park     410         10        31
# 7573   4081400   Queens  South Ozone Park     410         10        31
# 8081   4081400   Queens  South Ozone Park     410         10        31
# 8159   4083800   Queens  South Ozone Park     410         10        31
# 8345   4084000   Queens  South Ozone Park     410         10        31
# 8528   4010200   Queens  South Ozone Park     410         10        31
# 10116  4081400   Queens  South Ozone Park     410         10        31
# 13742  4016800   Queens  South Ozone Park     410         10        31
# 15149  4083800   Queens  South Ozone Park     410         10        31
# 18696  4084000   Queens  South Ozone Park     410         10        31
#
#        cncldist
# 1008         28
# 2135         28
# 2293         28
# 2439         28
# 2652         28
# 5601         28
# 5705         28
# 6808         28
# 7422         32
# 7573         28
# 8081         28
# 8159         32
# 8345         32
# 8528         28
# 10116        28
# 13742        28
# 15149        32
# 18696        32

# %%
filtered_data['health'].value_counts()
# Out:
# health
# 1    112
# 0     23
# 2     10
# Name: count, dtype: int64

# %%
filtered_data['zip_city'].value_counts()
# Out:
# zip_city
# South Ozone Park    145
# Name: count, dtype: int64

# %%
filtered_data['spc_common'].value_counts()
# Out:
# spc_common
# cherry                    16
# English oak               14
# pin oak                   12
# green ash                 10
# Norway maple               8
# white pine                 7
# London planetree           7
# honeylocust                7
# littleleaf linden          7
# American linden            6
# Callery pear               5
# Sophora                    5
# Japanese zelkova           4
# purple-leaf plum           3
# silver maple               3
# Chinese elm                3
# Japanese tree lilac        3
# ginkgo                     3
# silver linden              2
# Kentucky coffeetree        2
# sweetgum                   2
# willow oak                 2
# swamp white oak            2
# ash                        1
# red horse chestnut         1
# blue spruce                1
# red maple                  1
# 'Schubert' chokecherry     1
# dawn redwood               1
# American elm               1
# Japanese maple             1
# silver birch               1
# Turkish hazelnut           1
# hedge maple                1
# Oklahoma redbud            1
# Name: count, dtype: int64

# %%
train_date['spc_common'].unique().size
# Out:
# 120

# %%
train_date['spc_latin'].unique().size
# Out:
# 120

# %%
train_date['spc_common'].value_counts()
# Out:
# spc_common
# London planetree          2237
# pin oak                   2140
# cherry                    1689
# Japanese zelkova          1470
# littleleaf linden         1303
# English oak               1277
# green ash                 1089
# Callery pear              1076
# honeylocust               1034
# Norway maple               634
# Sophora                    545
# ginkgo                     517
# silver maple               422
# American elm               407
# American linden            336
# red maple                  278
# sweetgum                   219
# silver linden              203
# purple-leaf plum           196
# Chinese elm                192
# swamp white oak            183
# maple                      165
# crimson king maple         135
# eastern redbud             116
# 'Schubert' chokecherry      98
# Japanese tree lilac         93
# crab apple                  90
# dawn redwood                89
# northern red oak            88
# Siberian elm                81
# willow oak                  62
# sugar maple                 58
# golden raintree             58
# Amur maple                  52
# sawtooth oak                50
# black locust                48
# Kentucky coffeetree         48
# sycamore maple              44
# hawthorn                    39
# Schumard's oak              38
# hedge maple                 36
# scarlet oak                 34
# European hornbeam           34
# Amur maackia                33
# white oak                   31
# Atlantic white cedar        31
# eastern redcedar            31
# white ash                   30
# serviceberry                26
# catalpa                     26
# pitch pine                  25
# American hornbeam           25
# ash                         22
# American hophornbeam        22
# shingle oak                 21
# tulip-poplar                20
# bur oak                     20
# hardy rubber tree           19
# flowering dogwood           19
# Chinese fringetree          18
# sassafras                   18
# kousa dogwood               18
# black walnut                18
# weeping willow              16
# Cornelian cherry            16
# eastern cottonwood          16
# Ohio buckeye                15
# bald cypress                15
# Amur cork tree              15
# red horse chestnut          15
# Japanese maple              15
# horse chestnut              14
# blackgum                    13
# spruce                      13
# tree of heaven              13
# tartar maple                13
# katsura tree                12
# white pine                  12
# black oak                   12
# Atlas cedar                 12
# river birch                 12
# blue spruce                 11
# common hackberry            11
# crepe myrtle                10
# holly                       10
# silver birch                10
# Persian ironwood            10
# Japanese snowbell           10
# Shantung maple               9
# black cherry                 9
# paperbark maple              9
# arborvitae                   9
# trident maple                9
# Norway spruce                8
# empress tree                 8
# false cypress                8
# magnolia                     7
# Turkish hazelnut             7
# American beech               7
# cucumber magnolia            7
# pagoda dogwood               6
# Chinese tree lilac           6
# Oklahoma redbud              6
# paper birch                  6
# cockspur hawthorn            6
# quaking aspen                6
# Japanese hornbeam            6
# red pine                     6
# two-winged silverbell        6
# mulberry                     6
# pine                         5
# bigtooth aspen               4
# eastern hemlock              4
# southern magnolia            4
# European beech               3
# Chinese chestnut             3
# pignut hickory               3
# Kentucky yellowwood          2
# pond cypress                 1
# Himalayan cedar              1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(40, 6))
sns.histplot(data=train_date, x='spc_common', hue='health', multiple='stack', palette='viridis')
plt.title('Stacked Histogram of spc_common by Health')
plt.xlabel('spc_common')
plt.ylabel('Count')

# 凡例を表示
plt.legend(title='Health', loc='upper right', labels=['Health 0', 'Health 1', 'Health 2'])

# X軸のラベルを回転
plt.xticks(rotation=90, ha='right')

# グリッドを表示
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# 木によって健康か不健康かこの図のみではわからない

# %%
train_date['nta'].value_counts()
# Out:
# nta
# SI54    368
# SI11    359
# BK82    326
# BK45    306
# SI32    306
# SI01    300
# MN12    292
# QN46    285
# MN40    281
# QN17    267
# SI05    260
# QN49    246
# QN21    235
# QN45    222
# BK37    220
# BK42    216
# SI36    214
# QN15    213
# BK31    213
# BK75    213
# QN42    211
# SI48    211
# SI07    206
# QN20    195
# SI35    191
# SI25    191
# QN55    190
# BK33    189
# QN43    186
# QN03    185
# BK61    180
# QN57    178
# SI28    175
# SI24    174
# QN37    165
# BX09    165
# BK32    165
# QN05    165
# BK35    164
# QN51    163
# SI22    161
# QN44    161
# QN38    159
# BX52    154
# BK83    152
# MN25    151
# QN31    150
# SI37    149
# BK58    144
# BK17    143
# QN08    139
# SI12    138
# QN19    137
# QN66    134
# BK76    131
# SI45    128
# BK69    127
# QN48    125
# BX27    125
# BK85    123
# MN24    122
# BX36    122
# BK88    121
# QN01    120
# SI08    120
# BX10    119
# BK79    119
# QN56    118
# BK90    117
# QN23    116
# MN34    114
# QN06    114
# BK72    113
# MN23    111
# QN72    111
# BX31    108
# QN34    105
# QN30    104
# BK77    104
# QN10    103
# BX59    101
# QN28    101
# MN15     98
# BK38     98
# BX62     97
# QN60     96
# BK09     96
# MN32     93
# QN29     92
# MN09     92
# QN33     90
# BK43     90
# QN54     89
# BK73     89
# BK28     88
# MN14     87
# BK44     85
# SI14     84
# BX03     82
# MN19     82
# MN11     79
# MN03     79
# MN04     78
# BX01     78
# BK68     78
# BK25     76
# BK46     75
# QN76     74
# QN22     74
# MN28     74
# QN61     73
# BX49     72
# BX34     71
# BX14     70
# BK63     70
# MN01     68
# MN31     68
# QN47     67
# QN35     67
# QN27     66
# BX13     65
# QN70     64
# QN12     63
# BX35     62
# BX43     62
# MN33     61
# QN52     60
# BX22     59
# MN27     59
# QN50     59
# QN02     59
# BK34     58
# MN36     57
# BK96     57
# BK50     55
# BK81     55
# QN41     54
# QN25     54
# BX37     54
# QN63     53
# QN62     53
# BX55     52
# QN07     52
# BX06     51
# BK29     49
# BX39     47
# BK41     46
# MN35     45
# BX28     45
# BX75     44
# BX44     43
# BK78     42
# BX26     41
# BK21     41
# QN53     40
# BX08     40
# BK40     40
# BK95     40
# BX05     37
# BX29     37
# BK30     37
# BK64     36
# MN13     36
# BX07     35
# BK91     32
# QN18     30
# BK26     26
# MN06     25
# QN71     25
# BX63     24
# MN22     24
# BX33     22
# BX17     21
# BK93     21
# BX46     21
# BX40     19
# BK23     18
# BK19     18
# BX30     17
# BK60     15
# QN26     11
# BX41      8
# MN17      6
# MN21      5
# QN68      4
# BK27      2
# MN20      1
# Name: count, dtype: int64

# %%
# 日付ごとの可視化
date_counts = train_date['created_at'].value_counts().sort_index()

# 棒グラフで可視化
plt.figure(figsize=(100, 5))
sns.barplot(x=date_counts.index, y=date_counts.values)
plt.title('Number of Records by Date')
plt.xlabel('Date')
plt.ylabel('Count')
plt.xticks(rotation=45)  # X軸の日付表示を回転させる（任意）

plt.show()

# %%
train_date['Month'] = train_date['created_at'].dt.to_period('M')

# catplotで可視化
plt.figure(figsize=(20, 7))
sns.catplot(x='Month', hue='health', kind='count', data=train_date, height=6, aspect=3)
plt.title('Number of Records by Month and Health (train_date)')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
test_date['Month'] = test_date['created_at'].dt.to_period('M')

# 月ごとのデータを集計
monthly_test_data = test_date.groupby('Month').size()

# 棒グラフで可視化
plt.figure(figsize=(30, 5))
sns.barplot(x=monthly_test_data.index.astype(str), y=monthly_test_data.values)
plt.title('Number of Records by Month(test_data)')
plt.xlabel('Month')
plt.ylabel('Count')

plt.show()

# %%
filtered_data['Month'] = filtered_data['created_at'].dt.to_period('M')

# 月ごとのデータを集計
monthly_filtered_data = filtered_data.groupby('Month').size()

# 棒グラフで可視化
plt.figure(figsize=(30, 5))
sns.barplot(x=monthly_filtered_data.index.astype(str), y=monthly_filtered_data.values)
plt.title('Number of Records by Month(park_data)')
plt.xlabel('Month')
plt.ylabel('Count')

plt.show()
# Out:
# C:\Users\wgkdj\AppData\Local\Temp\ipykernel_7112\3716565122.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Month'] = filtered_data['created_at'].dt.to_period('M')

# %% [markdown]
# 日付について..
# #分布はトレーニングとテストで期間は変わらず、分布も似通っている。このことから同時期にとられたデータをなんらかの規則で分けたのではないかと推察する
# データが作成された日付が10月めっちゃ多い　→　何らかの理由があるはずでは？
# なぜか2016年のデータが前年の2015年の同じ月に比べて少ない　→　何らかの理由があるはずでは？　気温が関係していると思われる　←　NYCのみのデータだから気温はNYCのみ見ればオーケイ
